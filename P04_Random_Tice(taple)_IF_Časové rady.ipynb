# %% [markdown]
# # Kurz Python Jupyter - 4. časť

# %% [markdown]
# # 01. Random, Math

# %%
import random
print("Obsah modulu random -->", dir(random))

# Pseudonahodne cislo 0.0 <= < 1.0
print("nahodne cislo (0-1)", random.random())
# Komenter Ctrl + /
# print(random.__doc__)


# Normalne rozdelenie(distribution) Gaussovka
# Pseudonahodne cislo 0.0 <= x <= 100
# Intellisense Ctrl + space (medzera)
print("0.0 <= x <= 100 -->", random.uniform(0,100))
print("1-6 -->",random.randint(1,6))
print("Nahodnw 4 bajty -->", random.randbytes(4))

import math
print("\nObsah modulu math -->", dir(math))
print("\nDokumentacia math -->", math.__doc__)
# print("\nPomocnik math -->", help(math))
print("ludolfovo cislo -->", math.pi)
print("Eulerova konstanta -->", math.e)
print("Ceil zaokruhli smerom nahor na najblissie cele cislo -->", math.ceil(5.001))
print("Floor zaokruhli smerom nadol na najblissie cele cislo -->", math.ceil(5.999))
print("Zaokruhlenie klasicke round -->", round(5.5))
print("Zaokruhlenie klasicke round -->", round(5.3))

print("Cele cislo 0-10 -->", math.floor(random.uniform(0,10)))
# Cele cislo integer 0-6 inkluzivne (vratane) 6
print(random.randrange(6))

# Cele cislo integer 1-6 inkluzivne (vratane) 6
print(random.randrange(1,6))

print(random.choice(["vyhra","prehra","remiza"]))
print(random.choice(["XL","L","M","S"]))

#Rozdelenie retazca a miesanie
balicek_karty = "eso  kral  kralovna dolnik hornik" .split()
print("Pred zamiesanim -->", balicek_karty)
random.shuffle(balicek_karty)
print("Po zamiesani -->", balicek_karty)
# Out:
# Obsah modulu random --> ['BPF', 'LOG4', 'NV_MAGICCONST', 'RECIP_BPF', 'Random', 'SG_MAGICCONST', 'SystemRandom', 'TWOPI', '_Sequence', '_Set', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_e', '_exp', '_floor', '_inst', '_log', '_os', '_pi', '_random', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', '_warn', 'betavariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'normalvariate', 'paretovariate', 'randbytes', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']
# nahodne cislo (0-1) 0.765818043185486
# 0.0 <= x <= 100 --> 53.940593024029546
# 1-6 --> 6
# Nahodnw 4 bajty --> b'\xe9\x08m\xdf'
#
# Obsah modulu math --> ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']
#
# Dokumentacia math --> This module provides access to the mathematical functions
# defined by the C standard.
# ludolfovo cislo --> 3.141592653589793
# Eulerova konstanta --> 2.718281828459045
# Ceil zaokruhli smerom nahor na najblissie cele cislo --> 6
# Floor zaokruhli smerom nadol na najblissie cele cislo --> 6
# Zaokruhlenie klasicke round --> 6
# Zaokruhlenie klasicke round --> 5
# Cele cislo 0-10 --> 3
# 0
# 4
# remiza
# XL
# Pred zamiesanim --> ['eso', 'kral', 'kralovna', 'dolnik', 'hornik']
# Po zamiesani --> ['dolnik', 'hornik', 'eso', 'kralovna', 'kral']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31712\3557712799.py in <module>
#      42 print("Po zamiesani -->", balicek_karty)
#      43
# ---> 44 print(random.sample(100,3))
#
# C:\ProgramData\Anaconda3\lib\random.py in sample(self, population, k, counts)
#     431             population = tuple(population)
#     432         if not isinstance(population, _Sequence):
# --> 433             raise TypeError("Population must be a sequence.  For dicts or sets, use sorted(d).")
#     434         n = len(population)
#     435         if counts is not None:
#
# TypeError: Population must be a sequence.  For dicts or sets, use sorted(d).

# %% [markdown]
# # 02. Štruktúra If

# %% [markdown]
# Vetvenie, rozhodovanie...
# Keď budem mať 18 rokov, tak potom...
# Keď sa najem, tak potom....
# A číslo bude menšie ako 5, tak potom
# > < <= >= == != insinstance issuclass

# %%
# = Operator priradenia, ulozenie, assigment
a = 3
b = 35.3

# =- Operator porovnania, rovnosti
5 == 5 # True
5 == 6 # False

# =- Operator nerovnosti, roznosti
5 != 5 # False
5 != 6 # True

vstup = input("Hadaj na co myslim: ")

if vstup == "mesto":
    print("Myslis na mesto...")
# elif - else if    
elif vstup == "zviera":
    print("Myslis na zviera...")
elif vstup == "meno":
    print("Myslis na meno...") 
elif vstup == "vec":
    print("Myslis na vec...") 
else:
    print("Neuhadol si, Myslel som na -->", vstup)
# Out:
# Hadaj na co myslim: pivo
# Neuhadol si, Myslel som na --> pivo

# %%
meno = input("Zadaj svoje meno: ")
if not meno:
    print("Nezadal si meno, zadal si meno bez znakov")
else:
    print("Volas sa -->", meno)
# Out:
# Zadaj svoje meno: Martin
# Volas sa --> Martin

# %% [markdown]
# # 03. Časove rady (Time series)

# %%
# XLSX, XLS, XLSM, XLSB
# CSV ciarka/bodkociarka/tab/medzera oddelene hodnoty
# TSV tab oddelene hodnoty
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# Nacitali sme data z CVS
data_produkty = pd.read_csv("IT-Academy.csv", sep=";")
# print(data_produkty)

# Chceme dataframe/tabulku
df_data_produkty = pd.DataFrame(data_produkty, columns = ["Datum","Cena"])

# Chceme vlastne indexy cez datumy
df_data_produkty.index = df_data_produkty["Datum"]
del df_data_produkty["Datum"]

df_data_produkty.plot(figsize=(12,10))

plt.xlabel("Datum")
plt.ylabel("Ceny uhlia")
plt.title("Casove rady")
plt.show()
